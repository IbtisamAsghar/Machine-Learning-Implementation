# %%
# !pip install Pandas

# %%
import pandas as pd

# %%
df = pd.read_csv("/content/data_Lec13.csv")

# %%
df.head()
# Out:
#   Make       Model  Year             Engine Fuel Type  Engine HP  \
# 0  BMW  1 Series M  2011  premium unleaded (required)      335.0
# 1  BMW    1 Series  2011  premium unleaded (required)      300.0
# 2  BMW    1 Series  2011  premium unleaded (required)      300.0
# 3  BMW    1 Series  2011  premium unleaded (required)      230.0
# 4  BMW    1 Series  2011  premium unleaded (required)      230.0
#
#    Engine Cylinders Transmission Type     Driven_Wheels  Number of Doors  \
# 0               6.0            MANUAL  rear wheel drive              2.0
# 1               6.0            MANUAL  rear wheel drive              2.0
# 2               6.0            MANUAL  rear wheel drive              2.0
# 3               6.0            MANUAL  rear wheel drive              2.0
# 4               6.0            MANUAL  rear wheel drive              2.0
#
#                          Market Category Vehicle Size Vehicle Style  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11914 entries, 0 to 11913
# Data columns (total 16 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Make               11914 non-null  object
#  1   Model              11914 non-null  object
#  2   Year               11914 non-null  int64
#  3   Engine Fuel Type   11911 non-null  object
#  4   Engine HP          11845 non-null  float64
#  5   Engine Cylinders   11884 non-null  float64
#  6   Transmission Type  11914 non-null  object
#  7   Driven_Wheels      11914 non-null  object
#  8   Number of Doors    11908 non-null  float64
#  9   Market Category    8172 non-null   object
#  10  Vehicle Size       11914 non-null  object
#  11  Vehicle Style      11914 non-null  object
#  12  highway MPG        11914 non-null  int64
#  13  city mpg           11914 non-null  int64
#  14  Popularity         11914 non-null  int64
#  15  MSRP               11914 non-null  int64
# ...

# %%
df.shape
# Out:
# (11914, 16)

# %%
df["Year"].max()
# Out:
# 2017

# %%
df.loc[3,"Year"]
# Out:
# np.int64(2011)

# %%
df.describe()
# Out:
#                Year    Engine HP  Engine Cylinders  Number of Doors  \
# count  11914.000000  11845.00000      11884.000000     11908.000000
# mean    2010.384338    249.38607          5.628829         3.436093
# std        7.579740    109.19187          1.780559         0.881315
# min     1990.000000     55.00000          0.000000         2.000000
# 25%     2007.000000    170.00000          4.000000         2.000000
# 50%     2015.000000    227.00000          6.000000         4.000000
# 75%     2016.000000    300.00000          6.000000         4.000000
# max     2017.000000   1001.00000         16.000000         4.000000
#
#         highway MPG      city mpg    Popularity          MSRP
# count  11914.000000  11914.000000  11914.000000  1.191400e+04
# mean      26.637485     19.733255   1554.911197  4.059474e+04
# std        8.863001      8.987798   1441.855347  6.010910e+04
# min       12.000000      7.000000      2.000000  2.000000e+03
# ...

# %%
df.loc[[
    1,2,3,4,5
]]
# Out:
#   Make     Model  Year             Engine Fuel Type  Engine HP  \
# 1  BMW  1 Series  2011  premium unleaded (required)      300.0
# 2  BMW  1 Series  2011  premium unleaded (required)      300.0
# 3  BMW  1 Series  2011  premium unleaded (required)      230.0
# 4  BMW  1 Series  2011  premium unleaded (required)      230.0
# 5  BMW  1 Series  2012  premium unleaded (required)      230.0
#
#    Engine Cylinders Transmission Type     Driven_Wheels  Number of Doors  \
# 1               6.0            MANUAL  rear wheel drive              2.0
# 2               6.0            MANUAL  rear wheel drive              2.0
# 3               6.0            MANUAL  rear wheel drive              2.0
# 4               6.0            MANUAL  rear wheel drive              2.0
# 5               6.0            MANUAL  rear wheel drive              2.0
#
#            Market Category Vehicle Size Vehicle Style  highway MPG  city mpg  \
# ...

# %%
df.loc[[
    1,2,3,4
],['Make','Year' , 'Transmission Type']]
# Out:
#   Make  Year Transmission Type
# 1  BMW  2011            MANUAL
# 2  BMW  2011            MANUAL
# 3  BMW  2011            MANUAL
# 4  BMW  2011            MANUAL

# %%
df.sort_values(by='Year')
# Out:
#             Make               Model  Year                Engine Fuel Type  \
# 9415  Mitsubishi               Sigma  1990                regular unleaded
# 6514        Ford  LTD Crown Victoria  1990                regular unleaded
# 6515        Ford  LTD Crown Victoria  1990                regular unleaded
# 6516        Ford  LTD Crown Victoria  1990                regular unleaded
# 6517        Ford  LTD Crown Victoria  1990                regular unleaded
# ...          ...                 ...   ...                             ...
# 6490       Lexus              LS 460  2017     premium unleaded (required)
# 6491       Lexus              LS 460  2017     premium unleaded (required)
# 6492       Lexus              LS 460  2017     premium unleaded (required)
# 6344  Mitsubishi              Lancer  2017                regular unleaded
# 7391  Mitsubishi           Outlander  2017  premium unleaded (recommended)
#
# ...

# %%
df.loc[df['Engine HP'] == 142.0]
# Out:
#              Make     Model  Year  Engine Fuel Type  Engine HP  \
# 6373     Chrysler  Le Baron  1994  regular unleaded      142.0
# 6374     Chrysler  Le Baron  1994  regular unleaded      142.0
# 9415   Mitsubishi     Sigma  1990  regular unleaded      142.0
# 10013       Dodge   Stratus  2004  regular unleaded      142.0
#
#        Engine Cylinders Transmission Type      Driven_Wheels  Number of Doors  \
# 6373                6.0         AUTOMATIC  front wheel drive              4.0
# 6374                6.0         AUTOMATIC  front wheel drive              4.0
# 9415                6.0         AUTOMATIC  front wheel drive              4.0
# 10013               4.0         AUTOMATIC  front wheel drive              2.0
#
#       Market Category Vehicle Size Vehicle Style  highway MPG  city mpg  \
# 6373              NaN      Compact         Sedan           24        18
# 6374              NaN      Compact         Sedan           26        18
# ...

# %%
df['saal'] = df['Year']
df.head()
# Out:
#   Make       Model  Year             Engine Fuel Type  Engine HP  \
# 0  BMW  1 Series M  2011  premium unleaded (required)      335.0
# 1  BMW    1 Series  2011  premium unleaded (required)      300.0
# 2  BMW    1 Series  2011  premium unleaded (required)      300.0
# 3  BMW    1 Series  2011  premium unleaded (required)      230.0
# 4  BMW    1 Series  2011  premium unleaded (required)      230.0
#
#    Engine Cylinders Transmission Type     Driven_Wheels  Number of Doors  \
# 0               6.0            MANUAL  rear wheel drive              2.0
# 1               6.0            MANUAL  rear wheel drive              2.0
# 2               6.0            MANUAL  rear wheel drive              2.0
# 3               6.0            MANUAL  rear wheel drive              2.0
# 4               6.0            MANUAL  rear wheel drive              2.0
#
#                          Market Category Vehicle Size Vehicle Style  \
# ...

# %%
df = df.drop('saal' , axis=1)

# %%
df.head()
# Out:
#   Make       Model  Year             Engine Fuel Type  Engine HP  \
# 0  BMW  1 Series M  2011  premium unleaded (required)      335.0
# 1  BMW    1 Series  2011  premium unleaded (required)      300.0
# 2  BMW    1 Series  2011  premium unleaded (required)      300.0
# 3  BMW    1 Series  2011  premium unleaded (required)      230.0
# 4  BMW    1 Series  2011  premium unleaded (required)      230.0
#
#    Engine Cylinders Transmission Type     Driven_Wheels  Number of Doors  \
# 0               6.0            MANUAL  rear wheel drive              2.0
# 1               6.0            MANUAL  rear wheel drive              2.0
# 2               6.0            MANUAL  rear wheel drive              2.0
# 3               6.0            MANUAL  rear wheel drive              2.0
# 4               6.0            MANUAL  rear wheel drive              2.0
#
#                          Market Category Vehicle Size Vehicle Style  \
# ...

# %%
df.index = df['Transmission Type']

# %%
df.head()
# Out:
#                   Make       Model  Year             Engine Fuel Type  \
# Transmission Type
# MANUAL             BMW  1 Series M  2011  premium unleaded (required)
# MANUAL             BMW    1 Series  2011  premium unleaded (required)
# MANUAL             BMW    1 Series  2011  premium unleaded (required)
# MANUAL             BMW    1 Series  2011  premium unleaded (required)
# MANUAL             BMW    1 Series  2011  premium unleaded (required)
#
#                    Engine HP  Engine Cylinders Transmission Type  \
# Transmission Type
# MANUAL                 335.0               6.0            MANUAL
# MANUAL                 300.0               6.0            MANUAL
# MANUAL                 300.0               6.0            MANUAL
# MANUAL                 230.0               6.0            MANUAL
# MANUAL                 230.0               6.0            MANUAL
#
#                       Driven_Wheels  Number of Doors  \
# Transmission Type
# ...

# %%
df.index = df['Year']

# %%
df.head()
# Out:
#      Make       Model  Year             Engine Fuel Type  Engine HP  \
# Year
# 2011  BMW  1 Series M  2011  premium unleaded (required)      335.0
# 2011  BMW    1 Series  2011  premium unleaded (required)      300.0
# 2011  BMW    1 Series  2011  premium unleaded (required)      300.0
# 2011  BMW    1 Series  2011  premium unleaded (required)      230.0
# 2011  BMW    1 Series  2011  premium unleaded (required)      230.0
#
#       Engine Cylinders Transmission Type     Driven_Wheels  Number of Doors  \
# Year
# 2011               6.0            MANUAL  rear wheel drive              2.0
# 2011               6.0            MANUAL  rear wheel drive              2.0
# 2011               6.0            MANUAL  rear wheel drive              2.0
# 2011               6.0            MANUAL  rear wheel drive              2.0
# 2011               6.0            MANUAL  rear wheel drive              2.0
#
#                             Market Category Vehicle Size Vehicle Style  \
# Year
# ...

# %%
df.tail()
df['Year'].dtype
# Out:
# dtype('int64')

# %%
days_of_week = ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday']
df['Day'] = [days_of_week[i % 7] for i in range(len(df))]

# %%
df.head()
# Out:
#      Make       Model  Year             Engine Fuel Type  Engine HP  \
# Year
# 2011  BMW  1 Series M  2011  premium unleaded (required)      335.0
# 2011  BMW    1 Series  2011  premium unleaded (required)      300.0
# 2011  BMW    1 Series  2011  premium unleaded (required)      300.0
# 2011  BMW    1 Series  2011  premium unleaded (required)      230.0
# 2011  BMW    1 Series  2011  premium unleaded (required)      230.0
#
#       Engine Cylinders Transmission Type     Driven_Wheels  Number of Doors  \
# Year
# 2011               6.0            MANUAL  rear wheel drive              2.0
# 2011               6.0            MANUAL  rear wheel drive              2.0
# 2011               6.0            MANUAL  rear wheel drive              2.0
# 2011               6.0            MANUAL  rear wheel drive              2.0
# 2011               6.0            MANUAL  rear wheel drive              2.0
#
#                             Market Category Vehicle Size Vehicle Style  \
# Year
# ...

# %%
df.index = df['Day']

# %%
df.head()
# Out:
#           Make       Model  Year             Engine Fuel Type  Engine HP  \
# Day
# Monday     BMW  1 Series M  2011  premium unleaded (required)      335.0
# Tuesday    BMW    1 Series  2011  premium unleaded (required)      300.0
# Wednesday  BMW    1 Series  2011  premium unleaded (required)      300.0
# Thursday   BMW    1 Series  2011  premium unleaded (required)      230.0
# Friday     BMW    1 Series  2011  premium unleaded (required)      230.0
#
#            Engine Cylinders Transmission Type     Driven_Wheels  \
# Day
# Monday                  6.0            MANUAL  rear wheel drive
# Tuesday                 6.0            MANUAL  rear wheel drive
# Wednesday               6.0            MANUAL  rear wheel drive
# Thursday                6.0            MANUAL  rear wheel drive
# Friday                  6.0            MANUAL  rear wheel drive
#
#            Number of Doors                        Market Category  \
# Day
# ...

# %%
df.loc["Monday"]
# Out:
#          Make       Model  Year             Engine Fuel Type  Engine HP  \
# Day
# Monday    BMW  1 Series M  2011  premium unleaded (required)      335.0
# Monday    BMW    1 Series  2012  premium unleaded (required)      300.0
# Monday    BMW    1 Series  2013  premium unleaded (required)      230.0
# Monday   Audi         100  1992             regular unleaded      172.0
# Monday   Audi         100  1994             regular unleaded      172.0
# ...       ...         ...   ...                          ...        ...
# Monday    GMC       Yukon  2017     flex-fuel (unleaded/E85)      355.0
# Monday    BMW          Z3  2001  premium unleaded (required)      225.0
# Monday    BMW        Z4 M  2008  premium unleaded (required)      330.0
# Monday    BMW          Z4  2016  premium unleaded (required)      300.0
# Monday  Acura         ZDX  2011  premium unleaded (required)      300.0
#
#         Engine Cylinders Transmission Type     Driven_Wheels  Number of Doors  \
# Day
# ...

# %%
df.head()
# Out:
#   Make       Model  Year             Engine Fuel Type  Engine HP  \
# 0  BMW  1 Series M  2011  premium unleaded (required)      335.0
# 1  BMW    1 Series  2011  premium unleaded (required)      300.0
# 2  BMW    1 Series  2011  premium unleaded (required)      300.0
# 3  BMW    1 Series  2011  premium unleaded (required)      230.0
# 4  BMW    1 Series  2011  premium unleaded (required)      230.0
#
#    Engine Cylinders Transmission Type     Driven_Wheels  Number of Doors  \
# 0               6.0            MANUAL  rear wheel drive              2.0
# 1               6.0            MANUAL  rear wheel drive              2.0
# 2               6.0            MANUAL  rear wheel drive              2.0
# 3               6.0            MANUAL  rear wheel drive              2.0
# 4               6.0            MANUAL  rear wheel drive              2.0
#
#                          Market Category Vehicle Size Vehicle Style  \
# ...

# %%
# we can also do slicing in the loc

df.loc[1:21 ,['Make','Year','Engine Cylinders']]
# Out:
#     Make  Year  Engine Cylinders
# 1    BMW  2011               6.0
# 2    BMW  2011               6.0
# 3    BMW  2011               6.0
# 4    BMW  2011               6.0
# 5    BMW  2012               6.0
# 6    BMW  2012               6.0
# 7    BMW  2012               6.0
# 8    BMW  2012               6.0
# 9    BMW  2013               6.0
# 10   BMW  2013               6.0
# 11   BMW  2013               6.0
# 12   BMW  2013               6.0
# 13   BMW  2013               6.0
# 14   BMW  2013               6.0
# 15   BMW  2013               6.0
# 16   BMW  2013               6.0
# 17  Audi  1992               6.0
# 18  Audi  1992               6.0
# 19  Audi  1992               6.0
# 20  Audi  1992               6.0
# 21  Audi  1992               6.0

# %%
import pandas as pd

# %%
bios = pd.read_csv("/content/bios.csv")

# %%
bios.head()
# Out:
#    athlete_id                   name   born_date    born_city  \
# 0           1  Jean-François Blanchy  1886-12-12     Bordeaux
# 1           2         Arnaud Boetsch  1969-04-01       Meulan
# 2           3           Jean Borotra  1898-08-13     Biarritz
# 3           4        Jacques Brugnon  1895-05-11  Paris VIIIe
# 4           5           Albert Canet  1878-04-17   Wandsworth
#
#             born_region born_country     NOC  height_cm  weight_kg   died_date
# 0               Gironde          FRA  France        NaN        NaN  1960-10-02
# 1              Yvelines          FRA  France      183.0       76.0         NaN
# 2  Pyrénées-Atlantiques          FRA  France      183.0       76.0  1994-07-17
# 3                 Paris          FRA  France      168.0       64.0  1978-03-20
# 4               England          GBR  France        NaN        NaN  1930-07-25

# %%
bios.loc[bios['height_cm'] > 210].head()
# Out:
#       athlete_id                   name   born_date        born_city  \
# 5089        5108     Viktor Pankrashkin  1957-06-19  Moskva (Moscow)
# 5572        5595        Santiago Aldama  1968-12-07             Quel
# 5583        5606   Paulinho Villas Boas  1963-01-26        São Paulo
# 5599        5622      Vladimir Andreyev  1945-06-14        Astrakhan
# 5609        5632        Franjo Arapović  1965-06-02              NaN
#
#      born_region born_country                 NOC  height_cm  weight_kg  \
# 5089      Moskva       Russia        Soviet Union      220.0      112.0
# 5572    La Rioja        Spain               Spain      213.0       98.0
# 5583   São Paulo       Brazil              Brazil      217.0      106.0
# 5599   Astrakhan       Russia        Soviet Union      215.0       90.0
# 5609         NaN          NaN  Croatia Yugoslavia      211.0      120.0
#
#        died_date
# 5089  1993-07-24
# 5572         NaN
# 5583         NaN
# 5599         NaN
# 5609         NaN

# %%
bios.loc[bios['height_cm'] > 210 ,['name','height_cm']].head()

# %%
bios.loc[bios['height_cm'] > 210,['name','height_cm']]
# Out:
#                        name  height_cm
# 5089     Viktor Pankrashkin      220.0
# 5572        Santiago Aldama      213.0
# 5583   Paulinho Villas Boas      217.0
# 5599      Vladimir Andreyev      215.0
# 5609        Franjo Arapović      211.0
# 5673         Gunther Behnke      221.0
# 5681           Walt Bellamy      211.0
# 5683   Aleksandr Belostenny      214.0
# 5689             Tom Bender      213.0
# 5716               Uwe Blab      218.0
# 5781         Tommy Burleson      223.0
# 5796          Andy Campbell      218.0
# 5894             Mel Counts      213.0
# 5989            Vlade Divac      213.0
# 5992                 Olívia      211.0
# 6002           Zdeněk Douša      212.0
# 6059          Patrick Ewing      213.0
# 6068    Panagiotis Fasoulas      213.0
# 6070         Sten Feldreich      211.0
# 6077                Rolando      214.0
# 6106        Marc Freiberger      211.0
# 6160         Valery Goborov      211.0
# 6223            Lars Hansen      216.0
# ...

# %%
bios[bios['height_cm'] > 210][['name','height_cm']]
# Out:
#                        name  height_cm
# 5089     Viktor Pankrashkin      220.0
# 5572        Santiago Aldama      213.0
# 5583   Paulinho Villas Boas      217.0
# 5599      Vladimir Andreyev      215.0
# 5609        Franjo Arapović      211.0
# 5673         Gunther Behnke      221.0
# 5681           Walt Bellamy      211.0
# 5683   Aleksandr Belostenny      214.0
# 5689             Tom Bender      213.0
# 5716               Uwe Blab      218.0
# 5781         Tommy Burleson      223.0
# 5796          Andy Campbell      218.0
# 5894             Mel Counts      213.0
# 5989            Vlade Divac      213.0
# 5992                 Olívia      211.0
# 6002           Zdeněk Douša      212.0
# 6059          Patrick Ewing      213.0
# 6068    Panagiotis Fasoulas      213.0
# 6070         Sten Feldreich      211.0
# 6077                Rolando      214.0
# 6106        Marc Freiberger      211.0
# 6160         Valery Goborov      211.0
# 6223            Lars Hansen      216.0
# ...

# %% [markdown]
# **Filtering the data with the multiple condition checking**

# %%
bios[(bios['height_cm'] > 210) & (bios['born_country'] == "RUS")]
# Out:
#       athlete_id                name   born_date        born_city  \
# 5089        5108  Viktor Pankrashkin  1957-06-19  Moskva (Moscow)
# 5599        5622   Vladimir Andreyev  1945-06-14        Astrakhan
# 6715        6748        Vitaly Nosov  1968-02-01  Moskva (Moscow)
# 7188        7226  Vladimir Tkachenko  1957-09-20        Golovinka
#
#          born_region born_country           NOC  height_cm  weight_kg  \
# 5089          Moskva          RUS  Soviet Union      220.0      112.0
# 5599       Astrakhan          RUS  Soviet Union      215.0       90.0
# 6715          Moskva          RUS  Unified Team      214.0      118.0
# 7188  Krasnodar Kray          RUS  Soviet Union      220.0      110.0
#
#        died_date
# 5089  1993-07-24
# 5599         NaN
# 6715         NaN
# 7188         NaN

# %% [markdown]
# **Performing more filteration with string operation and regular expression (regx)**

# %%
bios[bios['name'].str.contains("Keith|Patrick",case=False)]
# Out:
#        athlete_id                           name   born_date  \
# 6               7                  Patrick Chila  1969-11-27
# 119           120               Patrick Wheatley  1899-01-20
# 319           320              Patrick De Koning  1961-04-23
# 1897         1907                   Keith Hanlon  1966-09-01
# 2115         2125                   Patrick Jopp  1962-01-08
# 2454         2465              Patrick Birocheau  1955-09-23
# 3505         3517                  Keith Wallace  1961-03-29
# 4314         4328                 Patrick Waweru  1956-06-09
# 5829         5852                   Patrick Cham  1953-05-18
# 6059         6085                  Patrick Ewing  1962-08-05
# 6228         6255                  Keith Hartley  1940-10-15
# 8391         8437                Patrick Lihanda  1962-04-11
# 8894         8942                 Patrick Mwamba  1964-01-04
# 8898         8946                    Keith Mwila  1966-01-01
# ...

# %%
bios[bios['name'].str.contains("Keith|Patrick",case=False,regex=False)]
# Out:
# Empty DataFrame
# Columns: [athlete_id, name, born_date, born_city, born_region, born_country, NOC, height_cm, weight_kg, died_date]
# Index: []

# %%
bios[bios['born_country'].isin(['USA','FRA','GBR']) & (bios['name'].str.startswith("Patrick"))]
# Out:
#       athlete_id               name   born_date        born_city  \
# 6              7      Patrick Chila  1969-11-27      Ris-Orangis
# 5829        5852       Patrick Cham  1953-05-18     Saint-Claude
# 9592        9646  Patrick Lancereau  1966-07-18            Tours
# 9598        9652   Patrick Lefoulon  1958-05-06  Mantes-la-Jolie
#
#          born_region born_country     NOC  height_cm  weight_kg died_date
# 6            Essonne          FRA  France      180.0       73.0       NaN
# 5829      Guadeloupe          FRA  France      195.0        NaN       NaN
# 9592  Indre-et-Loire          FRA  France      176.0       75.0       NaN
# 9598        Yvelines          FRA  France      175.0       73.0       NaN

# %%
bios.shape
# Out:
# (14236, 10)

# %% [markdown]
# **Pandas querey functions**

# %%
bios.query('born_country == "USA"' and 'height_cm > 210')
# Out:
#       athlete_id                   name   born_date               born_city  \
# 5089        5108     Viktor Pankrashkin  1957-06-19         Moskva (Moscow)
# 5572        5595        Santiago Aldama  1968-12-07                    Quel
# 5583        5606   Paulinho Villas Boas  1963-01-26               São Paulo
# 5599        5622      Vladimir Andreyev  1945-06-14               Astrakhan
# 5609        5632        Franjo Arapović  1965-06-02                     NaN
# 5673        5696         Gunther Behnke  1963-01-19              Leverkusen
# 5681        5704           Walt Bellamy  1937-07-24                New Bern
# 5683        5706   Aleksandr Belostenny  1959-02-24                   Odesa
# 5689        5712             Tom Bender  1944-09-27                     NaN
# 5716        5739               Uwe Blab  1962-03-26        München (Munich)
# 5781        5804         Tommy Burleson  1952-02-24               Crossnore
# ...

# %%
bios.head()
# Out:
#    athlete_id                   name   born_date    born_city  \
# 0           1  Jean-François Blanchy  1886-12-12     Bordeaux
# 1           2         Arnaud Boetsch  1969-04-01       Meulan
# 2           3           Jean Borotra  1898-08-13     Biarritz
# 3           4        Jacques Brugnon  1895-05-11  Paris VIIIe
# 4           5           Albert Canet  1878-04-17   Wandsworth
#
#             born_region born_country     NOC  height_cm  weight_kg  \
# 0               Gironde          FRA  France        NaN        NaN
# 1              Yvelines          FRA  France      183.0       76.0
# 2  Pyrénées-Atlantiques          FRA  France      183.0       76.0
# 3                 Paris          FRA  France      168.0       64.0
# 4               England          GBR  France        NaN        NaN
#
#     died_date  Price
# 0  1960-10-02     45
# 1         NaN     45
# 2  1994-07-17     45
# 3  1978-03-20     45
# 4  1930-07-25     45

# %%
bios.drop(columns = ['athlete_id','Price'])
# Out:
#                         name   born_date    born_city           born_region  \
# 0      Jean-François Blanchy  1886-12-12     Bordeaux               Gironde
# 1             Arnaud Boetsch  1969-04-01       Meulan              Yvelines
# 2               Jean Borotra  1898-08-13     Biarritz  Pyrénées-Atlantiques
# 3            Jacques Brugnon  1895-05-11  Paris VIIIe                 Paris
# 4               Albert Canet  1878-04-17   Wandsworth               England
# ...                      ...         ...          ...                   ...
# 14231           Hans Fischer  1961-01-29     Pomerode        Santa Catarina
# 14232        Joseph Fischler         NaN          NaN                   NaN
# 14233       Colin Fitzgerald  1955-11-26          NaN                   NaN
# 14234           Léon Flameng  1877-04-30  Paris XVIIe                 Paris
# 14235           Helge Fladby  1894-12-08         Oslo                  Oslo
#
# ...

# %%
bios_new = bios.copy()

# %%
import pandas as pd

# %%
data = pd.read_csv("/content/data_Lec13.csv")

# %%
data.head()
# Out:
#   Make       Model  Year             Engine Fuel Type  Engine HP  \
# 0  BMW  1 Series M  2011  premium unleaded (required)      335.0
# 1  BMW    1 Series  2011  premium unleaded (required)      300.0
# 2  BMW    1 Series  2011  premium unleaded (required)      300.0
# 3  BMW    1 Series  2011  premium unleaded (required)      230.0
# 4  BMW    1 Series  2011  premium unleaded (required)      230.0
#
#    Engine Cylinders Transmission Type     Driven_Wheels  Number of Doors  \
# 0               6.0            MANUAL  rear wheel drive              2.0
# 1               6.0            MANUAL  rear wheel drive              2.0
# 2               6.0            MANUAL  rear wheel drive              2.0
# 3               6.0            MANUAL  rear wheel drive              2.0
# 4               6.0            MANUAL  rear wheel drive              2.0
#
#                          Market Category Vehicle Size Vehicle Style  \
# ...

# %%
data.tail()
# Out:
#           Make   Model  Year                Engine Fuel Type  Engine HP  \
# 11909    Acura     ZDX  2012     premium unleaded (required)      300.0
# 11910    Acura     ZDX  2012     premium unleaded (required)      300.0
# 11911    Acura     ZDX  2012     premium unleaded (required)      300.0
# 11912    Acura     ZDX  2013  premium unleaded (recommended)      300.0
# 11913  Lincoln  Zephyr  2006                regular unleaded      221.0
#
#        Engine Cylinders Transmission Type      Driven_Wheels  Number of Doors  \
# 11909               6.0         AUTOMATIC    all wheel drive              4.0
# 11910               6.0         AUTOMATIC    all wheel drive              4.0
# 11911               6.0         AUTOMATIC    all wheel drive              4.0
# 11912               6.0         AUTOMATIC    all wheel drive              4.0
# 11913               6.0         AUTOMATIC  front wheel drive              4.0
#
# ...

# %%
data.isna().sum()
# Out:
# Make                    0
# Model                   0
# Year                    0
# Engine Fuel Type        3
# Engine HP              69
# Engine Cylinders       30
# Transmission Type       0
# Driven_Wheels           0
# Number of Doors         6
# Market Category      3742
# Vehicle Size            0
# Vehicle Style           0
# highway MPG             0
# city mpg                0
# Popularity              0
# MSRP                    0
# dtype: int64

# %%
data.isnull().sum()
# Out:
# Make                    0
# Model                   0
# Year                    0
# Engine Fuel Type        3
# Engine HP              69
# Engine Cylinders       30
# Transmission Type       0
# Driven_Wheels           0
# Number of Doors         6
# Market Category      3742
# Vehicle Size            0
# Vehicle Style           0
# highway MPG             0
# city mpg                0
# Popularity              0
# MSRP                    0
# dtype: int64

# %%
data.dtypes
# Out:
# Make                  object
# Model                 object
# Year                   int64
# Engine Fuel Type      object
# Engine HP            float64
# Engine Cylinders     float64
# Transmission Type     object
# Driven_Wheels         object
# Number of Doors      float64
# Market Category       object
# Vehicle Size          object
# Vehicle Style         object
# highway MPG            int64
# city mpg               int64
# Popularity             int64
# MSRP                   int64
# dtype: object

# %%
data.fillna(data['Engine HP'].mean() , inplace=True)

# %%
data['Engine HP'].isna().sum()
# Out:
# 0

# %%
data['Engine Cylinders']=data['Engine Cylinders'].interpolate()

# %%
data['Engine Cylinders'].isna().sum()
# Out:
# 0

# %%
data.dropna(data['Market Category'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-115-b0b0fb21ffc2> in <cell line: 1>()
# ----> 1 data.dropna(data['Market Category'])
#
# TypeError: DataFrame.dropna() takes 1 positional argument but 2 were given
